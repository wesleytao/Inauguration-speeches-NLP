# %%
from __future__ import print_function, unicode_literals, division
from bz2 import BZ2File
import time
import plac
import ujson
from spacy.matcher import PhraseMatcher
import spacy
import time 
import gc
from spacy import displacy
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # 1. Load Data

# %% [markdown]
# ## 1.1 Inaugural speech
# All the Inaugural speeches are store in a dicitonary. Keys are the title and values are the whole text.

# %%
speechpath=os.path.expanduser("~Wesle\Documents\GitHub\ADS_Teaching\Projects_StarterCodes\Project1-RNotebook\data\InauguralSpeeches")
speechpath=os.path.normpath(speechpath)
assert os.path.exists(speechpath)
# get the file names in the dir
filenames = os.listdir(speechpath)
# load all speeches in a dictionary
speechdict=dict()
for file in filenames:
    thispath= speechpath + "\\"+file
    with open(thispath,"br") as f:
        thisspeech=f.read().decode("utf-8")
        speechdict[file]=thisspeech

# %%
speechpath1=os.path.expanduser("~Wesle\Documents\GitHub\ADS_Teaching\Projects_StarterCodes\Project1-RNotebook\data")
speechpath1=os.path.normpath(speechpath1)
speechinfo=pd.read_excel(speechpath1+"//"+"InaugurationInfo.xlsx")
speechinfo.sort_values(by=["President","Term"],ascending=[1,1])
speechinfo[0:10]
# Out:
#            President              File  Term                        Party  \
# 0  George Washington  GeorgeWashington     1                          NaN
# 1  George Washington  GeorgeWashington     2                          NaN
# 2         John Adams         JohnAdams     1                    Fedralist
# 3   Thomas Jefferson   ThomasJefferson     1  Democratic-Republican Party
# 4   Thomas Jefferson   ThomasJefferson     2  Democratic-Republican Party
# 5      James Madison      JamesMadison     1  Democratic-Republican Party
# 6      James Madison      JamesMadison     2  Democratic-Republican Party
# 7       James Monroe       JamesMonroe     1  Democratic-Republican Party
# 8       James Monroe       JamesMonroe     2  Democratic-Republican Party
# 9  John Quincy Adams   JohnQuincyAdams     1  Democratic-Republican Party
#
#   Words
# 0  1431
# 1   135
# 2  2321
# 3  1730
# 4  2166
# 5  1177
# 6  1211
# 7  3375
# 8  4472
# 9  2915

# %%
speechdate=pd.read_table(speechpath1+"//"+"InauguationDates.txt",sep="\t")
speechdate=speechdate.rename(index=str, columns={"PRESIDENT":"President","FIRST": 1, "SECOND":2,"THIRD":3 ,"FOURTH":4})
speechdate=pd.melt(speechdate,id_vars=["President"],value_vars=[1,2,3,4])
speechdate=speechdate.loc[speechdate.value.notnull()]
speechdate=speechdate.rename(index=str,columns={"variable":"Term","value":"date"})
speechdate[1:10]
# Out:
#                 President Term      date
# 1              John Adams    1  3/4/1797
# 2        Thomas Jefferson    1  3/4/1801
# 3           James Madison    1  3/4/1809
# 4            James Monroe    1  3/4/1817
# 5       John Quincy Adams    1  3/4/1825
# 6          Andrew Jackson    1  3/4/1829
# 7        Martin Van Buren    1  3/4/1837
# 8  William Henry Harrison    1  3/4/1841
# 9              John Tyler    1  4/6/1841

# %%
mergeddata=pd.merge(speechinfo, speechdate, on=['President',"Term"], how='left')
mergeddata.replace(np.nan,"",regex=True)
mergeddata
# Out:
#                  President                  File Term  \
# 0        George Washington      GeorgeWashington    1
# 1        George Washington      GeorgeWashington    2
# 2               John Adams             JohnAdams    1
# 3         Thomas Jefferson       ThomasJefferson    1
# 4         Thomas Jefferson       ThomasJefferson    2
# 5            James Madison          JamesMadison    1
# 6            James Madison          JamesMadison    2
# 7             James Monroe           JamesMonroe    1
# 8             James Monroe           JamesMonroe    2
# 9        John Quincy Adams       JohnQuincyAdams    1
# 10          Andrew Jackson         AndrewJackson    1
# 11          Andrew Jackson         AndrewJackson    2
# 12        Martin van Buren        MartinvanBuren    1
# 13  William Henry Harrison  WilliamHenryHarrison    1
# 14           James K. Polk            JamesKPolk    1
# 15          Zachary Taylor         ZacharyTaylor    1
# 16         Franklin Pierce        FranklinPierce    1
# 17          James Buchanan         JamesBuchanan    1
# 18         Abraham Lincoln        AbrahamLincoln    1
# 19         Abraham Lincoln        AbrahamLincoln    2
# 20        Ulysses S. Grant         UlyssesSGrant    1
# 21        Ulysses S. Grant         UlyssesSGrant    2
# 22     Rutherford B. Hayes      RutherfordBHayes    1
# 23          James Garfield         JamesGarfield    1
# 24    Grover Cleveland - I     GroverCleveland-I    1
# 25       Benjamin Harrison      BenjaminHarrison    1
# 26   Grover Cleveland - II    GroverCleveland-II    2
# 27        William McKinley       WilliamMcKinley    1
# 28        William McKinley       WilliamMcKinley    2
# 29      Theodore Roosevelt     TheodoreRoosevelt    1
# 30     William Howard Taft     WilliamHowardTaft    1
# 31          Woodrow Wilson         WoodrowWilson    1
# 32          Woodrow Wilson         WoodrowWilson    2
# 33       Warren G. Harding        WarrenGHarding    1
# 34         Calvin Coolidge        CalvinCoolidge    1
# 35          Herbert Hoover         HerbertHoover    1
# 36   Franklin D. Roosevelt    FranklinDRoosevelt    1
# 37   Franklin D. Roosevelt    FranklinDRoosevelt    2
# 38   Franklin D. Roosevelt    FranklinDRoosevelt    3
# 39   Franklin D. Roosevelt    FranklinDRoosevelt    4
# 40         Harry S. Truman          HarrySTruman    1
# 41    Dwight D. Eisenhower     DwightDEisenhower    1
# 42    Dwight D. Eisenhower     DwightDEisenhower    2
# 43         John F. Kennedy          JohnFKennedy    1
# 44       Lyndon B. Johnson        LyndonBJohnson    1
# 45           Richard Nixon          RichardNixon    1
# 46           Richard Nixon          RichardNixon    2
# 47            Jimmy Carter           JimmyCarter    1
# 48           Ronald Reagan          RonaldReagan    1
# 49           Ronald Reagan          RonaldReagan    2
# 50             George Bush            GeorgeBush    1
# 51      William J. Clinton       WilliamJClinton    1
# 52      William J. Clinton       WilliamJClinton    2
# 53          George W. Bush           GeorgeWBush    1
# 54          George W. Bush           GeorgeWBush    2
# 55            Barack Obama           BarackObama    1
# 56            Barack Obama           BarackObama    2
# 57         Donald J. Trump          DonaldJTrump    1
#
#                           Party Words        date
# 0                           NaN  1431   4/30/1789
# 1                           NaN   135    3/4/1793
# 2                     Fedralist  2321    3/4/1797
# 3   Democratic-Republican Party  1730    3/4/1801
# 4   Democratic-Republican Party  2166    3/4/1805
# 5   Democratic-Republican Party  1177    3/4/1809
# 6   Democratic-Republican Party  1211    3/4/1813
# 7   Democratic-Republican Party  3375    3/4/1817
# 8   Democratic-Republican Party  4472    3/5/1821
# 9   Democratic-Republican Party  2915    3/4/1825
# 10                   Democratic  1128    3/4/1829
# 11                   Democratic  1176    3/4/1833
# 12                   Democratic  3843         NaN
# 13                         Whig  8460    3/4/1841
# 14                   Democratic  4809         NaN
# 15                         Whig  1090    3/5/1849
# 16                   Democratic  3336    3/4/1853
# 17                   Democratic  2831    3/4/1857
# 18                   Republican  3637    3/4/1861
# 19                   Republican   700    3/4/1865
# 20                   Republican  1127    3/4/1869
# 21                   Republican  1339    3/4/1873
# 22                   Republican  2486    3/5/1877
# 23                   Republican  2979         NaN
# 24                   Democratic  1686         NaN
# 25                   Republican  4392    3/4/1889
# 26                   Democratic  2015         NaN
# 27                   Republican  3968    3/4/1897
# 28                   Republican  2218    3/4/1901
# 29                   Republican   984   9/14/1901
# 30                   Republican  5434    3/4/1909
# 31                   Democratic  1704    3/4/1913
# 32                   Democratic  1526    3/5/1917
# 33                   Republican  3329    3/4/1921
# 34                   Republican  4055    8/3/1923
# 35                   Republican  3672    3/4/1929
# 36                   Democratic  1880    3/4/1933
# 37                   Democratic  1808   1/20/1937
# 38                   Democratic  1359   1/20/1941
# 39                   Democratic   559   1/20/1945
# 40                   Democratic  2273   4/12/1945
# 41                   Republican  2459   1/20/1953
# 42                   Republican  1658   1/21/1957
# 43                   Democratic  1366   1/20/1961
# 44                   Democratic  1507  11/22/1963
# 45                   Republican  2128         NaN
# 46                   Republican  1803         NaN
# 47                   Democratic  1229   1/20/1977
# 48                   Republican  2427   1/20/1981
# 49                   Republican  2561   1/21/1985
# 50                   Republican  2320   1/20/1989
# 51                   Democratic  1598   1/20/1993
# 52                   Democratic  2155   1/20/1997
# 53                   Republican  1592   1/20/2001
# 54                   Republican  2071   1/20/2005
# 55                   Democratic  2395   1/20/2009
# 56                   Democratic  2096   1/21/2013
# 57                   Republican   TBD   1/20/2017

# %%
for president,file,term,party,word,date in mergeddata.values:
    if pd.isnull(date):
        print(president)
# Out:
# Martin van Buren
# James K. Polk
# James Garfield
# Grover Cleveland - I
# Grover Cleveland - II
# Richard Nixon
# Richard Nixon

# %%
speechdate
# Out:
#                   President Term       date
# 0         George Washington    1  4/30/1789
# 1                John Adams    1   3/4/1797
# 2          Thomas Jefferson    1   3/4/1801
# 3             James Madison    1   3/4/1809
# 4              James Monroe    1   3/4/1817
# 5         John Quincy Adams    1   3/4/1825
# 6            Andrew Jackson    1   3/4/1829
# 7          Martin Van Buren    1   3/4/1837
# 8    William Henry Harrison    1   3/4/1841
# 9                John Tyler    1   4/6/1841
# 10          James Knox Polk    1   3/4/1845
# 11           Zachary Taylor    1   3/5/1849
# 12         Millard Fillmore    1  7/10/1850
# 13          Franklin Pierce    1   3/4/1853
# 14           James Buchanan    1   3/4/1857
# 15          Abraham Lincoln    1   3/4/1861
# 16           Andrew Johnson    1  4/15/1865
# 17         Ulysses S. Grant    1   3/4/1869
# 18      Rutherford B. Hayes    1   3/5/1877
# 19        James A. Garfield    1   3/4/1881
# 20           Chester Arthur    1  9/20/1881
# 21         Grover Cleveland    1   3/4/1885
# 22        Benjamin Harrison    1   3/4/1889
# 24         William McKinley    1   3/4/1897
# 25       Theodore Roosevelt    1  9/14/1901
# 26      William Howard Taft    1   3/4/1909
# 27           Woodrow Wilson    1   3/4/1913
# 28        Warren G. Harding    1   3/4/1921
# 29          Calvin Coolidge    1   8/3/1923
# 30           Herbert Hoover    1   3/4/1929
# ..                      ...  ...        ...
# 38             Jimmy Carter    1  1/20/1977
# 39            Ronald Reagan    1  1/20/1981
# 40              George Bush    1  1/20/1989
# 41       William J. Clinton    1  1/20/1993
# 42           George W. Bush    1  1/20/2001
# 43             Barack Obama    1  1/20/2009
# 44          Donald J. Trump    1  1/20/2017
# 45        George Washington    2   3/4/1793
# 47         Thomas Jefferson    2   3/4/1805
# 48            James Madison    2   3/4/1813
# 49             James Monroe    2   3/5/1821
# 51           Andrew Jackson    2   3/4/1833
# 60          Abraham Lincoln    2   3/4/1865
# 62         Ulysses S. Grant    2   3/4/1873
# 68         Grover Cleveland    2   3/4/1893
# 69         William McKinley    2   3/4/1901
# 70       Theodore Roosevelt    2   3/4/1905
# 72           Woodrow Wilson    2   3/5/1917
# 74          Calvin Coolidge    2   3/4/1925
# 76    Franklin D. Roosevelt    2  1/20/1937
# 77          Harry S. Truman    2  1/20/1949
# 78     Dwight D. Eisenhower    2  1/21/1957
# 80        Lyndon B. Johnson    2  1/20/1965
# 81         Richard M. Nixon    2  1/20/1973
# 84            Ronald Reagan    2  1/21/1985
# 86       William J. Clinton    2  1/20/1997
# 87           George W. Bush    2  1/20/2005
# 88             Barack Obama    2  1/21/2013
# 121   Franklin D. Roosevelt    3  1/20/1941
# 166   Franklin D. Roosevelt    4  1/20/1945
#
# [67 rows x 3 columns]

# %% [markdown]
# ## 1.2 Chopus
# There are 5 external chopus that will be used in this project. <br>
# Sources are listed below
# ###  en_core_web_sm  (The built-in chopus of spacy )
# English multi-task CNN trained on OntoNotes, with GloVe vectors trained on Common Crawl. Assigns word vectors, context-specific token vectors, POS tags, dependency parse and named entities.
# <br>
# https://spacy.io/models/en#en_core_web_sm

# %% [markdown]
# ### CET 4 & CET 6 :

# %%
cet4path=os.path.expanduser("~Wesle\Documents\GitHub\ADS_Teaching\Projects_StarterCodes\Project1-RNotebook\data\cet-4.txt")
cet4path=os.path.normpath(cet4path)
assert os.path.exists(cet4path)    
cet4=pd.read_table(cet4path)
def get_string(thislist):
    return thislist[1]
cet4=cet4.iloc[:,0].str.split('"').apply(get_string)
# cet4s=" ".join(list(cet4.values))
# prossessedcet4=FileProcessor(cet4s)
# CET4set=set(prossessedcet4.SelectQualified().text)

# %%
cet6path=os.path.expanduser("~Wesle\Documents\GitHub\ADS_Teaching\Projects_StarterCodes\Project1-RNotebook\data\cet-6.txt")
cet6path=os.path.normpath(cet6path)
cet6=pd.read_table(cet6path)
def get_string(thislist):
    return thislist[1]
cet6=cet6.iloc[:,0].str.split('"').apply(get_string)

# %% [markdown]
# ### TOEFL & GRE :

# %%
path=os.path.expanduser("~Wesle\Documents\GitHub\ADS_Teaching\Projects_StarterCodes\Project1-RNotebook\data")
toefl=path+"//"+"TOEFL.txt"
GRE=path+"//"+"GRE.txt"
with open(GRE,"br") as f:
    a=f.read().decode("utf-8")
GRE=a.split("\r\n")
GRE = filter(None, GRE)
GRE=list(GRE)
GRE=[word.replace("\xa0","")for word in GRE]
GRE=[word.replace("\ufeff","")for word in GRE]

# %%
with open(toefl,"br") as f:
    a=f.read().decode("utf-8")
    TOEFL=a.split("\r\n")
# print(len(TOEFL))
TOEFL = filter(None, TOEFL)
TOEFL=list(TOEFL)
# print(len(TOEFL))
TOEFL=[word.replace("\xa0","")for word in TOEFL]
TOEFL=[word.replace(" ","")for word in TOEFL]
# Out:
# 2866
# 2865
# ['abandon',
#  'abashed',
#  'abate',
#  'abdicate',
#  'abduct',
#  'abhor',
#  'abhorrent',
#  'ability',
#  'ablaze',
#  'abnormal']

# %% [markdown]
# Since thoses lists have overlap, we have to make each word set disjoint by exluding the low-level words form high level word lists
# The suggested rank of word list are as follows:
# CET4 < CET6 < TOEFL < GRE

# %%
GREset   =set(GRE)-set(TOEFL)-set(cet6)-set(cet4)
TOEFLset =set(TOEFL)-set(cet6)-set(cet4)
CET6set  =set(cet6)-set(cet4)
CET4set  =set(cet4)
# Out:
# 5525

# %% [markdown]
# ### Wiki- 100000:
# https://gist.github.com/h3xx/1976236/revisions
#  This is a list of the top 100,000 m It was compiled in August 2005 and

# %%
wikipath=os.path.expanduser("~Wesle\Documents\GitHub\google-10000-english\wiki-100k.txt")
wikipath=os.path.normpath(wikipath)
assert os.path.exists(wikipath)
wiki100k=pd.read_table(wikipath,header= None)
wiki100k.drop(wiki100k.index[:26], inplace=True) # the first 26 are empty string 
wiki100k=wiki100k.iloc[:,0].unique() # get rid of replicate

# %%
len(set(wiki100k))
# Out:
# 84401

# %% [markdown]
# ## 1.3 word number

# %%
corpusdf=pd.DataFrame([[len(CET4set),"CET4"],[len(CET6set),"CET6"],[len(TOEFLset),"TOEFL"],[len(GREset),"GRE"],[len(wiki100k),"wiki"]],columns=["length","name"])

# %%
corpusdf
# Out:
#    length   name
# 0    4126   CET4
# 1    1123   CET6
# 2    1459  TOEFL
# 3    5525    GRE
# 4   84401   wiki

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('CET4', 'CET6', 'TOEFL', 'GRE', 'Wiki')
y_pos = np.arange(len(objects))
performance = [4126,1123,1459,5525,88401]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Word Count')
plt.title('The Total Word Count')
plt.show()

# %% [markdown]
# # 2 Parsing and tokenization using spacy

# %% [markdown]
# ## 2.1 token & word

# %%
class FileProcessor():
    ''' we need pandas,spacy to function'''
    def __init__(self,speech,model="en"):
        self.nlp=spacy.load(model)
        self.doc=nlp(speech)
        self.wordnum=len(self.doc)
        self.trivnum=len(self.doc)-len(self.SelectQualified())
        
    def GetTokenDF(self):
        """we want to get the whole dataframe with token details with the help of pandas """
        tokendf=pd.DataFrame(columns=["text","lemma","pos","tag","dep","is_stop"])
        for token in self.doc:
            tokendf.loc[token.text]=[token.text, token.lemma_ ,token.pos_, token.tag_, token.dep_, token.is_stop]
        return tokendf
    
    def SelectQualified(self):
        """this is to select qualified words display in dataframe"""
        tokendf=self.GetTokenDF()
        sampleset=["PROPN","NOUN","VERB","ADJ","ADV"] # pick only noun verb adj and adv words
        Qtoken=tokendf.loc[(tokendf.pos.isin(sampleset))& (tokendf.is_stop == False)] # is_stop  means the trivial words "of the a" 
        return Qtoken
    
    def GetEntityDF(self):
        """get entity data frame excluding cardinal and ordinal"""
        entitydf=pd.DataFrame(columns="text,start_char,end_char,label".split(","))
        for ent in self.doc.ents:
            entitydf.loc[ent.text]=[ent.text, ent.start_char, ent.end_char, ent.label_]
            entitydf=entitydf.loc[(entitydf.label!="CARDINAL") & (entitydf.label!="ORDINAL")] # cardinal and ordinal are not what we want
        return entitydf
    
    def GetWordChunkDF(self):
        """get word chunk  dataframe"""
        samplechunk=pd.DataFrame(columns="text, root.text, root.dep_,head.text".split(","))
        for chunk in self.doc.noun_chunks:
            samplechunk.loc[chunk.text]=[chunk.text, chunk.root.text, chunk.root.dep_,chunk.root.head.text]
        return samplechunk
       
    def GetAvgDepth(self):
        
        def getdepth(token):
             # if right child exist search right child
            if not list(token.children):
                return 0
            else:
                leftmax= 0 if not list(token.lefts) else max([getdepth(i)  for i in token.lefts])
            # if left child exist search leftchild
                rightmax=0  if not list(token.rights) else max([getdepth(i)  for i in token.rights])
                return max(leftmax,rightmax)+1
            # if not child return 0
            # return the max number
        count=0
        mydepth=dict()
        for token in self.doc:
            if token.dep_=="ROOT":
                # iterating each dep and get the depth
                count=count+1
                mydepth[count]=getdepth(token)
        return(sum(mydepth.values())/count)
    def GetAvgSenlen(self):
        sentences = [sent.string.strip() for sent in doc1.sents]
        return len(self.doc)/len(sentences)

# %%
prossessed=FileProcessor(samplespeech)

# %%
prossessed.GetAvgDepth()
# Out:
# 6.157894736842105

# %%
prossessed.GetAvgSenlen()
# Out:
# 30.278195488721803

# %%
prossessed.GetTokenDF()[0:2]
# Out:
#           text   lemma    pos  tag       dep is_stop
#                         SPACE                  False
# Fellow  Fellow  fellow  PROPN  NNP  compound   False

# %%
prossessed.SelectQualified()[0:2]
# Out:
#               text     lemma    pos   tag       dep is_stop
# Fellow      Fellow    fellow  PROPN   NNP  compound   False
# Citizens  Citizens  citizens  PROPN  NNPS      ROOT   False

# %%
prossessed.GetEntityDF()[0:2]
# Out:
#                                                                         text  \
#  Fellow-Citizens of the United States   Fellow-Citizens of the United States
# Constitution                                                    Constitution
#
#                                       start_char end_char label
#  Fellow-Citizens of the United States          0       37   ORG
# Constitution                               19686    19698   LAW

# %%
prossessed.GetWordChunkDF()[0:2]
# Out:
#                                 text  root.text  root.dep_ head.text
#  Fellow-Citizens     Fellow-Citizens   Citizens       ROOT  Citizens
# the United States  the United States     States       pobj        to

# %%
# dataframe

# %% [markdown]
# # 3 Matching and dictionary annotation

# %%
class WordCount():
    def __init__(self):
        #cet 4 build dictionary check
        cet4matcher =PhraseMatcher(nlp.vocab)
        patterns4=[nlp(text) for text in CET4set]
        cet4matcher.add('cet4', None, *patterns4)
        self.cet4matcher=cet4matcher 
        
        #cet 6 build dictionary check
        matcher6=PhraseMatcher(nlp.vocab)
        patterns6=[nlp(text) for text in CET6set]
        matcher6.add('cet6', None, *patterns6)
        self.cet6matcher=matcher6 
        
        # toefl matcher
        matchertoefl=PhraseMatcher(nlp.vocab)
        patternstoefl=[nlp(text) for text in TOEFLset]
        matchertoefl.add('teofl', None, *patternstoefl)
        self.toeflmatcher= matchertoefl
        
        # gre matcher
        matcherGRE=PhraseMatcher(nlp.vocab)
        patternsGRE=[nlp(text) for text in GREset]
        matchertoefl.add('teofl', None, *patternsGRE)
        self.grematcher= matcherGRE
          
    def get_cet4(self,doc):
        return(len(self.cet4matcher(doc)))
    
    def get_cet6(self,doc):
        return(len(self.cet6matcher(doc)))
    
    def get_gre(self,doc):
        return(len(self.grematcher(doc)))
    
    def get_toefl(self,doc):
        return(len(self.toeflmatcher(doc)))

# %%
# %%time
wordcount=WordCount()
# Out:
# Wall time: 1min 55s

# %%
wordcount.get_cet4(doc1)
# Out:
# 2645

# %%
wordcount.get_cet6(doc1)
# Out:
# 47

# %%
wordcount.get_gre(doc1)
# Out:
# 0

# %% [markdown]
# # 4  Word Complexity Scoring System

# %%
class ScoreGrader():
    def __init__(self,freqlist)
        score=dict()
        for i in range(len(freqlist)):
            score[freqlist[i]]=i
        self.scoreboard=score
        
    def get_score(self,df):
        thisscore=0
        not_recognized=-1
        view=dict()
        for i in range(len(df)):
            try:
                thisscore=thisscore+self.scoreboard[df.iloc[i,1]]
            except KeyError as e:
                not_recognized = not_recognized+1
                view[not_recognized]=str(df.iloc[i,1])
                
        return [thisscore,view]

# %%
sampleQW[1:4]
# len(google1w)
# Out:
#               text     lemma    pos   tag       dep is_stop
# Citizens  Citizens  citizens  PROPN  NNPS      ROOT   False
# United      United    united  PROPN   NNP  compound   False
# States      States    states  PROPN  NNPS      pobj   False

# %%
len(sampleQW)
# Out:
# 865

# %%
len(wiki100k)
# Out:
# 84401

# %%
sampleQW.iloc[1,1]
# Out:
# 'citizens'

# %%
score["citizen"]
# Out:
# 4257

# %%
score["Christianity"]
# Out:
# 3965

# %%
sampleQW[1:2]
# Out:
#               text     lemma    pos   tag   dep is_stop
# Citizens  Citizens  citizens  PROPN  NNPS  ROOT   False

# %% [markdown]
# # 5 Syntax complexity

# %% [markdown]
# # 6 Document Similarity Check

# %%
nlp = spacy.load('en_core_web_lg')
tokens = nlp(u'dog cat banana sasquatch')

for token in tokens:
    print(token.text, token.has_vector, token.vector_norm, token.is_oov)
# Out:
# dog True 7.0336733 False
# cat True 6.6808186 False
# banana True 6.700014 False
# sasquatch True 6.9789977 False

# %%
nlp = spacy.load('en_vectors_web_lg')

doc1 = nlp(u"The labrador barked.")
doc2 = nlp(u"The labrador swam.")
doc3 = nlp(u"the labrador people live in canada.")

for doc in [doc1, doc2, doc3]:
    labrador = doc[1]
    dog = nlp(u"dog")
    print(labrador.similarity(dog))
# Out:
# 0.6349026162476088
# 0.6349026162476088
# 0.6349026162476088

# %%
# %%time
a=speechdict[list(speechdict.keys())[0]]
b=speechdict[list(speechdict.keys())[1]]
doc1=nlp(a)
doc2=nlp(b)
# Out:
# Wall time: 150 ms

# %%
doc1.similarity(doc2)
# Out:
# 0.9919007913397163

# %%
doc3=nlp(u"alaksjdf;l askdjf rth dgnmsjybkw asdjfkl  abce concerned")
doc3.similarity(doc1)
# Out:
# 0.29674399972356263

# %%
doc1 = nlp(u"Paris is the largest city in France.")
doc2 = nlp(u"Vilnius is the capital of Lithuania.")
doc3 = nlp(u"An emu is a large bird.")

for doc in [doc1, doc2, doc3]:
    for other_doc in [doc1, doc2, doc3]:
        print(doc.similarity(other_doc))
# Out:
# 0.9999999534417695
# 0.7554965262954281
# 0.6921461821156969
# 0.7554965262954281
# 1.000000059691864
# 0.5668025741640493
# 0.6921461821156969
# 0.5668025741640493
# 1.0000000494093304

# %% [markdown]
# # Annotation Display

# %%
import spacy
from spacy import displacy

text = """But Google is starting from behind. The company made a late push
into hardware, and Apple’s Siri, available on iPhones, and Amazon’s Alexa
software, which runs on its Echo and Dot devices, have clear leads in
consumer adoption."""

nlp = spacy.load('en_core_web_sm')
doc = nlp(text)
displacy.serve(doc, style='ent')
# Out:
#     Serving on port 5000...
#     Using the 'ent' visualizer
# 127.0.0.1 - - [28/Jan/2018 12:03:58] "GET / HTTP/1.1" 200 4108
# 127.0.0.1 - - [28/Jan/2018 12:03:59] "GET /favicon.ico HTTP/1.1" 200 4108
# 127.0.0.1 - - [28/Jan/2018 12:04:42] "GET / HTTP/1.1" 200 4108
# 127.0.0.1 - - [28/Jan/2018 12:04:43] "GET /favicon.ico HTTP/1.1" 200 4108
#     Shutting down server on port 5000.
